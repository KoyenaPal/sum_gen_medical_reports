# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=False)
root_dir = "/content/gdrive/My Drive/masters_thesis/"
base_dir = root_dir

# %%
df = pd.read_csv(root_dir + "t5_all_setup1_testing_custom_model_generated_summaries_april_22_beam_10.csv")

# %%
counter = 0
generated_counter = 0
for label, content in df.iterrows():
  actual = content[0].split("Service:")
  generated = content[1].split("Service:")
  actual = [data.strip() for data in actual]
  service = actual[1].split("\n")[0]
  generated = [data.strip() for data in generated]
  if len(generated) > 1:
    generated_counter += 1
    if service in generated[1]:
      counter += 1
print(counter)
print(generated_counter)
